# %% [markdown]
# # Oefeningen op indexen
#
# ## Oefening 1
# Wat is het dtype van de onderstaande index?
# 1. str
# 2. pd.StringDtype
# 3. 'O' (object)
# 4. Je krijgt een foutmelding omdat een index altijd getallen moet bevatten

# %%
import pandas as pd
idx = pd.Index(['Karen', 'Kristel', 'Kathleen'])

# %% [markdown]
# ## Oefening 2
# Wat is het dtype van de onderstaande index?
# 1. str
# 2. pd.StringDtype
# 3. 'O' (object)
# 4. Je krijgt een foutmelding omdat een index unieke waarden moet bevatten

# %%
import pandas as pd
idx = pd.Index(['Karen', 'Kristel', 'Kathleen', 'Kathleen'])

# %% [markdown]
# ## Oefening 3
# Wat is het dtype van de onderstaande index?
# 1. str
# 2. pd.StringDtype
# 3. 'O' (object)
# 4. Je krijgt een foutmelding omdat een index geen 'lege'(None) waarden kan bevatten

# %%
import pandas as pd
idx = pd.Index(['Karen', 'Kristel', None])

# %% [markdown]
# ## Oefening 4
# Wat is de waarde van ser.index[0]?
# 1. Karen
# 2. Damen
# 3. Je krijgt een foutmelding omdat 0 niet in de index staat

# %%
import pandas as pd
ser = pd.Series(['Damen', 'Verbeke', 'Aerts'], index=['Karen', 'Kristel', 'Kathleen'])

# %% [markdown]
# ## Oefening 5
# Wat is de waarde van ser[0]?
# 1. Karen
# 2. Damen
# 3. Je krijgt een foutmelding omdat 0 niet in de index staat

# %%
import pandas as pd
ser = pd.Series(['Damen', 'Verbeke', 'Aerts'], index=['Karen', 'Kristel', 'Kathleen'])

# %% [markdown]
# ## Oefening 6
# Wat is de waarde van ser.index[-1] na het uitvoeren van de volgende code?
# 1. 'Josje'
# 2. Je krijgt een foutmelding omdat een indexwaarde 'immutable' is. (kan niet gewijzigd worden)
# 3. 'Kathleen'
# 4. Je krijgt een foutmelding omdat je -1 niet kunt gebruiken met een index

# %%
import pandas as pd
ser = pd.Series(['Damen', 'Verbeke', 'Aerts'], index=['Karen', 'Kristel', 'Josje'])
ser.index[-1] = 'Kristel'

# %% [markdown]
# ## Oefening 7
# Wat is de waarde van ser['Josje'] na het uitvoeren van de volgende code?
# 1. 'Huisman'
# 2. Je krijgt een foutmelding omdat een indexwaarde 'immutable' is. (kan niet gewijzgd worden)
# 3. 'Aerts'
# 4. Je krijgt een foutmelding omdat je 'Josje' niet kunt gebruiken als index van deze Series.

# %%
import pandas as pd
ser = pd.Series(['Damen', 'Verbeke', 'Aerts'], index=['Karen', 'Kristel', 'Josje'])
ser['Josje'] = 'Huisman'

# %% [markdown]
# ## Oefening 8
# Hoe kun je controleren of 'Kathleen' voorkomt in de index (meerdere antwoorden mogelijk)
# 1. Dat kun je niet controleren omdat deze code een fout geeft
# 2. 'Kathleen' in idx
# 3. idx['Kathleen'] in een try: ... except: ... constructie
# 4. len(idx['Kathleen']) > 0

# %%
import pandas as pd
idx = pd.Index('Karen', 'Kristel', 'Kathleen')

# %% [markdown]
# ## Oefening 9
# Wat wordt er getoond wanneer je ser.index[1:2:2] afdrukt?
# 1. 'Karen'
# 2. RangeIndex(start=1, stop=2, step=2)
# 3. 'Karen' en 'Kathleen'
# 4. Je krijgt een foutmelding omdat de slicing fout gedefinieerd is

# %%
import pandas as pd
ser = pd.Series(['Karen', 'Kristel', 'Kathleen', 'Josje', 'Hanne', 'Marthe', 'Klaasje', 'Julia', 'Nora'])

# %% [markdown]
# ## Oefening 10
# Wat wordt er getoond wanneer je ser_k3_1[ser_k3_1.index.intersection(ser_k3_2.index)] afdrukt?
# 1. 'Damen' en 'Verbeke'
# 2. Je krijgt een foutmelding omdat de intersection dubbele waarden oplevert
# 3. 'Karen Damen' en 'Kristel Verbeke'
# 4. 'Karen' en 'Kristel'

# %%
import pandas as pd
ser_k3_1 = pd.Series(['Damen', 'Verbeke', 'Aerts'], index=['Karen', 'Kristel', 'Kathleen'])
ser_k3_2 = pd.Series(['Damen', 'Verbeke', 'Huisman'], index=['Karen', 'Kristel', 'Josje'])
#ser_k3_1[ser_k3_1.index.intersection(ser_k3_2.index)]

# %% [markdown]
# ## Extra oefening
# Vertrek van de drie onderstaande series. Zorg ervoor dat je de volgende index maakt (de volgorde is niet belangrijk) door de drie indexen te combineren (in 1 statement):
# ```
# Index(['Hanne', 'Josje', 'Karen', 'Kathleen', 'Klaasje', 'Kristel', 'Marthe'], dtype='object')
# ```

# %%
import pandas as pd
ser_k3_1 = pd.Series(['Damen', 'Verbeke', 'Aerts'], index=['Karen', 'Kristel', 'Kathleen'])
ser_k3_2 = pd.Series(['Damen', 'Verbeke', 'Huisman'], index=['Karen', 'Kristel', 'Josje'])
ser_k3_3 = pd.Series(['Verbruggen', 'De Pillecyn', 'Meijer'], index=['Hanne', 'Marthe', 'Klaasje'])

# %% [markdown]
# # Oplossingen
# ## Oefening 1
# Het is een object want een index kan eender welke waarden bevatten(antwoord 3)
# ## Oefening 2
# Het is een object want de waarden moeten niet uniek zijn (antwoord 3)
# ## Oefening 3
# Het is een object want waarden mogelijk 'leeg' zijn (antwoord 3)
# ## Oefening 4
# Karen (antwoord 1) want een index is een 'gewone' array.
# ## Oefening 5
# In Pandas 3 zal het veranderen, maar voorlopig is het correcte antwoord nog 'Damen' (antwoord 2)
# ## Oefening 6
# Een index ondersteunt geen 'mutable operations' (wijzigingen) (antwoord 2)
# ## Oefening 7
# 'Huisman' want dit is een manier om een waarde van een Series te wijzigen (antwoord 1)
# ## Oefening 8
# De code geeft een fout omdat de index verkeerd gedefinieerd is (antwoord 1) maar 'Kathleen' in idx zou anders het correcte antwoord zijn (alhoewel de try... except... constructie ook werkt)
# ## Oefening 9
# De RangeIndex wordt getoond (antwoord 2)
# ## Oefening 10
# 'Karen Damen' en 'Kristel Verbeke' want je toont een series (index + waarde) en de intersection van twee indexen geeft de gemeenschappelijke elementen terug.
#
# ## Extra oefening
# Je kunt hiervoor 'union' gebruiken.
# ```
# ser_k3_1.index.union(ser_k3_2.index).union(ser_k3_3.index)
# ```
